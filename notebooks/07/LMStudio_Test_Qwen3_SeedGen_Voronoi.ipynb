# %%
# run LM Studio with local server enabled
# Batch-run N cases with LM Studio *grammar / schema constrained* output via response_format=json_schema
# - For each case: print INPUT_JSON + OUTPUT_JSON
# - Then display the Voronoi figure directly as cell output (one figure per case)

# %pip -q install -U numpy matplotlib requests shapely

import json, random
import requests
import numpy as np
import matplotlib.pyplot as plt

from shapely.geometry import MultiPoint, box
from shapely import voronoi_polygons

LMSTUDIO_URL = "http://localhost:1234/v1/chat/completions"
MODEL_NAME = "local-model"

# -----------------------------
# Input + prompt + call
# -----------------------------
def make_input(aspect_ratio=1.0, k=6, hotspot_count=8, seed=0):
    rng = np.random.default_rng(seed)
    random.seed(seed)
    ws = rng.dirichlet([0.8] * hotspot_count).tolist()
    hotspots = []
    for i in range(hotspot_count):
        hotspots.append({
            "x": random.random(),
            "y": random.random(),
            "weight": float(ws[i]),
            "radius": float(random.uniform(0.02, 0.10)),
        })
    return {"aspect_ratio": float(aspect_ratio), "k": int(k), "hotspots": hotspots}

def build_prompt(inp):
    k = inp["k"]
    return (
        "Place shard seed centers in a normalized 2D world.\n"
        "Coordinates are in [0,1]x[0,1]. The world aspect ratio is width/height.\n\n"
        f"INPUT_JSON:{json.dumps(inp, separators=(',',':'))}\n\n"
        "Return ONLY JSON (no extra text).\n"
        f"Return exactly {k} centers.\n"
        "Centers should be unique (no duplicates)."
    )

def make_response_schema_for_k(k: int):
    return {
        "name": "voronoi_centers",
        "schema": {
            "type": "object",
            "additionalProperties": False,
            "properties": {
                "centers": {
                    "type": "array",
                    "minItems": int(k),
                    "maxItems": int(k),
                    "items": {
                        "type": "object",
                        "additionalProperties": False,
                        "properties": {
                            "x": {"type": "number", "minimum": 0.0, "maximum": 1.0},
                            "y": {"type": "number", "minimum": 0.0, "maximum": 1.0},
                        },
                        "required": ["x", "y"],
                    },
                }
            },
            "required": ["centers"],
        },
    }

def call_model_constrained(prompt, k: int, temperature=0.2, timeout=120):
    schema = make_response_schema_for_k(k)
    payload = {
        "model": MODEL_NAME,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": float(temperature),
        "response_format": {"type": "json_schema", "json_schema": schema},
    }
    r = requests.post(LMSTUDIO_URL, json=payload, timeout=timeout)
    r.raise_for_status()
    return r.json()["choices"][0]["message"]["content"]

def extract_output_json_constrained(text):
    return json.loads(text.strip())

# -----------------------------
# Shapely Voronoi helpers
# -----------------------------
def _dedupe_points(pts: np.ndarray, eps: float = 1e-10) -> np.ndarray:
    # Quantize to grid then unique (prevents pathological duplicates)
    q = np.round(pts / eps) * eps
    _, idx = np.unique(q, axis=0, return_index=True)
    return pts[np.sort(idx)]

def _jitter_points(pts: np.ndarray, scale: float, seed: int) -> np.ndarray:
    rng = np.random.default_rng(seed)
    return pts + rng.normal(scale=scale, size=pts.shape)

def _sanitize_points_for_shapely(
    pts: np.ndarray,
    xmin: float, xmax: float, ymin: float, ymax: float,
    seed: int = 0,
) -> np.ndarray:
    # Shapely/GEOS is more tolerant than Qhull but still benefits from de-dupe.
    pts_u = _dedupe_points(pts, eps=1e-10)

    if pts_u.shape[0] < 2:
        # If the model produced identical centers, jitter to get something drawable.
        pts_u = _jitter_points(pts, scale=1e-6, seed=seed)
        pts_u = _dedupe_points(pts_u, eps=1e-12)

    pts_u[:, 0] = np.clip(pts_u[:, 0], xmin, xmax)
    pts_u[:, 1] = np.clip(pts_u[:, 1], ymin, ymax)
    return pts_u

def _shapely_voronoi_polys(pts_xy: np.ndarray, xmin, xmax, ymin, ymax, tolerance=1e-10):
    """
    Returns polygons clipped/extended to bbox.
    If input is degenerate, this may raise; caller can retry with jitter.
    """
    extent = box(xmin, ymin, xmax, ymax)
    mp = MultiPoint([tuple(p) for p in pts_xy])

    gc = voronoi_polygons(
        mp,
        extend_to=extent,     # ensures we cover the whole rectangle
        tolerance=tolerance,  # snaps nearly-identical inputs
        only_edges=False
    )

    polys = list(gc.geoms) if hasattr(gc, "geoms") else list(gc)
    # Clip each polygon to bbox (extend_to usually handles, but clipping is cheap + safe)
    out = []
    for p in polys:
        if p.is_empty:
            continue
        out.append(p.intersection(extent))
    return out

# -----------------------------
# Plot
# -----------------------------
def plot_voronoi(inp, out_json):
    aspect = float(inp["aspect_ratio"])
    centers = out_json["centers"]
    hotspots = inp["hotspots"]

    # Convert normalized [0,1]x[0,1] to world coords [0,aspect]x[0,1]
    pts = np.array([[c["x"] * aspect, c["y"]] for c in centers], dtype=float)
    xmin, xmax, ymin, ymax = 0.0, aspect, 0.0, 1.0

    pts_u = _sanitize_points_for_shapely(pts, xmin, xmax, ymin, ymax, seed=0)

    polys = None
    # Retry with increasing jitter if GEOS rejects degenerate inputs
    for attempt, jitter in enumerate([0.0, 1e-12, 1e-9, 1e-6, 1e-4]):
        try_pts = pts_u if jitter == 0.0 else _sanitize_points_for_shapely(
            _jitter_points(pts_u, scale=jitter, seed=attempt),
            xmin, xmax, ymin, ymax, seed=attempt
        )
        try:
            polys = _shapely_voronoi_polys(try_pts, xmin, xmax, ymin, ymax, tolerance=1e-10)
            pts_u = try_pts
            break
        except Exception:
            polys = None
            continue

    if polys is None:
        raise RuntimeError("Shapely Voronoi failed; centers too degenerate even after jitter.")

    fig, ax = plt.subplots(figsize=(7.5, 5.5))
    ax.set_aspect("equal", adjustable="box")
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    for poly in polys:
        if poly.is_empty:
            continue
        # Handle MultiPolygon from intersection
        geoms = list(poly.geoms) if poly.geom_type == "MultiPolygon" else [poly]
        for g in geoms:
            x, y = g.exterior.xy
            ax.fill(x, y, alpha=0.15, linewidth=0)
            ax.plot(x, y, linewidth=1)

    ax.scatter(pts_u[:, 0], pts_u[:, 1], marker="x")

    for h in hotspots:
        hx, hy = h["x"] * aspect, h["y"]
        ax.scatter([hx], [hy], s=2000 * float(h["weight"]), alpha=0.5)
        ax.add_patch(plt.Circle((hx, hy), float(h["radius"]) * aspect, fill=False, linewidth=1))

    ax.set_title(f"Voronoi (Shapely) | k={inp['k']} | aspect={inp['aspect_ratio']} (unique={pts_u.shape[0]})")
    ax.set_xlabel("x (world)")
    ax.set_ylabel("y (world)")
    plt.show()

# -----------------------------
# Batch runner
# -----------------------------
results = []

def run_batch_display(n=5, aspect_ratio=1.5, k=6, hotspot_count=10, seed0=0, temperature=0.2):
    global results
    results = []

    for i in range(n):
        inp = make_input(aspect_ratio=aspect_ratio, k=k, hotspot_count=hotspot_count, seed=seed0 + i)
        prompt = build_prompt(inp)

        completion_text = call_model_constrained(prompt, k=inp["k"], temperature=temperature)
        out_json = extract_output_json_constrained(completion_text)

        results.append({"case": i, "input": inp, "output": out_json})

        print("=" * 80)
        print(f"CASE {i}")
        print("INPUT_JSON:")
        print(json.dumps(inp, indent=2))
        print("OUTPUT_JSON:")
        print(json.dumps(out_json, indent=2))

        plot_voronoi(inp, out_json)

run_batch_display(n=8, aspect_ratio=1, k=4, hotspot_count=6, seed0=42)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ================================================================================
# CASE 0
# INPUT_JSON:
# {
#   "aspect_ratio": 1.0,
#   "k": 4,
#   "hotspots": [
#     {
#       "x": 0.6394267984578837,
#       "y": 0.025010755222666936,
#       "weight": 0.27015161850680836,
#       "radius": 0.04200234546952954
#     },
#     {
#       "x": 0.22321073814882275,
#       "y": 0.7364712141640124,
#       "weight": 0.37857070572971513,
#       "radius": 0.0741359589938329
#     },
#     {
#       "x": 0.8921795677048454,
#       "y": 0.08693883262941615,
#       "weight": 0.011093358066999619,
#       "radius": 0.05375374557482164
#     },
#     {
#       "x": 0.029797219438070344,
#       "y": 0.21863797480360336,
#       "weight": 0.25790642266088076,
#       "radius": 0.060428423048268995
#     },
#     {
#       "x": 0.026535969683863625,
#       "y": 0.1988376506866485,
#       "weight": 0.016297618341568197,
#       "radius": 0.07199075502236185
#     },
#     {
#       "x": 0.5449414806032167,
#       "y": 0.2204406220406967,
#       "weight": 0.06598027669402785,
#       "radius": 0.06714125471007269
#     }
#   ]
# }
# OUTPUT_JSON:
# {
#   "centers": [
#     {
#       "x": 0.6394267984578837,
#       "y": 0.0250107552226669
#     },
#     {
#       "x": 0.2232107381488227,
#       "y": 0.7364712141640124
#     },
#     {
#       "x": 0.0297972194380703,
#       "y": 0.2186379748036033
#     },
#     {
#       "x": 0.5449414806032167,
#       "y": 0.2204406220406967
#     }
#   ]
# }
# ================================================================================
# CASE 1
# INPUT_JSON:
# {
#   "aspect_ratio": 1.0,
#   "k": 4,
#   "hotspots": [
#     {
#       "x": 0.038551839337380045,
#       "y": 0.6962243226370528,
#       "weight": 0.1343685112245836,
#       "radius": 0.03151465771162888
#     },
#     {
#       "x": 0.46253225482908755,
#       "y": 0.671646764117767,
#       "weight": 0.0012108889962575975,
#       "radius": 0.08343610173242355
#     },
#     {
#       "x": 0.45318922846621235,
#       "y": 0.4982722297980512,
#       "weight": 0.10828765657663994,
#       "radius": 0.021532568641947823
#     },
#     {
#       "x": 0.4323888389514402,
#       "y": 0.3723746808209262,
#       "weight": 0.1885251998297356,
#       "radius": 0.08818309065526825
#     },
#     {
#       "x": 0.5469839042910056,
#       "y": 0.755316838254966,
#       "weight": 0.06042134312695603,
#       "radius": 0.05472545110817874
#     },
#     {
#       "x": 0.17618810428468956,
#       "y": 0.8508752517946389,
#       "weight": 0.5071864002458273,
#       "radius": 0.0856175989654969
#     }
#   ]
# }
# OUTPUT_JSON:
# {
#   "centers": [
#     {
#       "x": 0.1761881042846895,
#       "y": 0.8508752517946389
#     },
#     {
#       "x": 0.4323888389514402,
#       "y": 0.3723746808209262
#     },
#     {
#       "x": 0.5469839042910056,
#       "y": 0.755316838254966
#     },
#     {
#       "x": 0.4531892284662123,
#       "y": 0.4982722297980512
#     }
#   ]
# }
# ================================================================================
# CASE 2
# INPUT_JSON:
# {
#   "aspect_ratio": 1.0,
#   "k": 4,
#   "hotspots": [
#     {
#       "x": 0.40853587925449375,
#       "y": 0.5419720091045962,
#       "weight": 0.016660072610636605,
#       "radius": 0.08896292931834186
#     },
#     {
#       "x": 0.17666564419544384,
#       "y": 0.2251595205781467,
#       "weight": 0.08182894718464366,
#       "radius": 0.022327780261448885
#     },
#     {
#       "x": 0.1166505334428638,
#       "y": 0.008805625887066904,
#       "weight": 0.062160795293885227,
#       "radius": 0.03253522680666911
#     },
#     {
#       "x": 0.5137132085026757,
#       "y": 0.989492910377551,
#       "weight": 0.1706370597999747,
#       "radius": 0.07548082091451505
#     },
#     {
#       "x": 0.37842657112328093,
#       "y": 0.4050477353192561,
#       "weight": 0.08361180909367312,
#       "radius": 0.07530477027299035
#     },
#     {
#       "x": 0.32611987261685993,
#       "y": 0.07355343057826824,
#       "weight": 0.5851013160171866,
#       "radius": 0.08732183175249673
#     }
#   ]
# }
# OUTPUT_JSON:
# {
#   "centers": [
#     {
#       "x": 0.3261198726168599,
#       "y": 0.0735534305782682
#     },
#     {
#       "x": 0.3784265711232809,
#       "y": 0.4050477353192561
#     },
#     {
#       "x": 0.5137132085026757,
#       "y": 0.989492910377551
#     },
#     {
#       "x": 0.1166505334428638,
#       "y": 0.0088056258870669
#     }
#   ]
# }
# ================================================================================
# CASE 3
# INPUT_JSON:
# {
#   "aspect_ratio": 1.0,
#   "k": 4,
#   "hotspots": [
#     {
#       "x": 0.2718754143840908,
#       "y": 0.48802820785090784,
#       "weight": 0.13134228444738405,
#       "radius": 0.026550347389693325
#     },
#     {
#       "x": 0.33873348699206973,
#       "y": 0.07233360770535402,
#       "weight": 0.24994327324044466,
#       "radius": 0.020882909366391998
#     },
#     {
#       "x": 0.28385029589876865,
#       "y": 0.11770636555802805,
#       "weight": 0.10616643540628115,
#       "radius": 0.04488305798496006
#     },
#     {
#       "x": 0.7434707928397064,
#       "y": 0.0357557155126923,
#       "weight": 0.2817455951552248,
#       "radius": 0.06999500457443773
#     },
#     {
#       "x": 0.13501116090704035,
#       "y": 0.7950712434655829,
#       "weight": 0.07352892468996092,
#       "radius": 0.07895740995056817
#     },
#     {
#       "x": 0.21101029956774453,
#       "y": 0.8480765801722641,
#       "weight": 0.1572734870607044,
#       "radius": 0.07738413776659225
#     }
#   ]
# }
# OUTPUT_JSON:
# {
#   "centers": [
#     {
#       "x": 0.28,
#       "y": 0.12
#     },
#     {
#       "x": 0.34,
#       "y": 0.07
#     },
#     {
#       "x": 0.74,
#       "y": 0.04
#     },
#     {
#       "x": 0.14,
#       "y": 0.85
#     }
#   ]
# }
# ================================================================================
# CASE 4
# INPUT_JSON:
# {
#   "aspect_ratio": 1.0,
#   "k": 4,
#   "hotspots": [
#     {
#       "x": 0.8882680764524881,
#       "y": 0.39999439597101294,
#       "weight": 0.3618909884390897,
#       "radius": 0.06708961462193858
#     },
#     {
#       "x": 0.8597866735427614,
#       "y": 0.22853920336460065,
#       "weight": 0.0322594554744808,
#       "radius": 0.06125738272188158
#     },
#     {
#       "x": 0.5837304855736061,
#       "y": 0.9471995219767291,
#       "weight": 0.12487317253274156,
#       "radius": 0.022574511188501418
#     },
#     {
#       "x": 0.06894367026654058,
#       "y": 0.3200841593158338,
#       "weight": 0.08415623879929499,
#       "radius": 0.08600736144450802
#     },
#     {
#       "x": 0.8431495877420079,
#       "y": 0.13539117983479798,
#       "weight": 0.22138701217484422,
#       "radius": 0.09356320160348526
#     },
#     {
#       "x": 0.5277693445209781,
#       "y": 0.9678965934609308,
#       "weight": 0.1754331325795489,
#       "radius": 0.0947615461126319
#     }
#   ]
# }
# OUTPUT_JSON:
# {
#   "centers": [
#     {
#       "x": 0.8882680764524881,
#       "y": 0.3999943959710129
#     },
#     {
#       "x": 0.8431495877420079,
#       "y": 0.1353911798347979
#     },
#     {
#       "x": 0.5837304855736061,
#       "y": 0.9471995219767291
#     },
#     {
#       "x": 0.0689436702665405,
#       "y": 0.3200841593158338
#     }
#   ]
# }
# ================================================================================
# CASE 5
# INPUT_JSON:
# {
#   "aspect_ratio": 1.0,
#   "k": 4,
#   "hotspots": [
#     {
#       "x": 0.35184625582788265,
#       "y": 0.430186245990098,
#       "weight": 0.16320326779838,
#       "radius": 0.05629366908716593
#     },
#     {
#       "x": 0.3434697408782532,
#       "y": 0.5124443649244089,
#       "weight": 0.06396014275202799,
#       "radius": 0.051393232116437745
#     },
#     {
#       "x": 0.04090872254284261,
#       "y": 0.4185326073961467,
#       "weight": 0.5095924897753413,
#       "radius": 0.02189278898082157
#     },
#     {
#       "x": 0.10245584696998078,
#       "y": 0.26380664067454207,
#       "weight": 0.019313294598574192,
#       "radius": 0.09724584745898525
#     },
#     {
#       "x": 0.48155277761710846,
#       "y": 0.5466877744282466,
#       "weight": 0.07567049659731269,
#       "radius": 0.0933923022840686
#     },
#     {
#       "x": 0.8987383567957395,
#       "y": 0.5675682084836022,
#       "weight": 0.16826030847836373,
#       "radius": 0.03840375616415848
#     }
#   ]
# }
# OUTPUT_JSON:
# {
#   "centers": [
#     {
#       "x": 0.042,
#       "y": 0.42
#     },
#     {
#       "x": 0.35,
#       "y": 0.43
#     },
#     {
#       "x": 0.89,
#       "y": 0.57
#     },
#     {
#       "x": 0.1,
#       "y": 0.26
#     }
#   ]
# }
# ================================================================================
# CASE 6
# INPUT_JSON:
# {
#   "aspect_ratio": 1.0,
#   "k": 4,
#   "hotspots": [
#     {
#       "x": 0.5481578284163297,
#       "y": 0.13189146337587565,
#       "weight": 0.08985200830560928,
#       "radius": 0.07692374738144196
#     },
#     {
#       "x": 0.3022500559178156,
#       "y": 0.938325274775271,
#       "weight": 0.14243866461969742,
#       "radius": 0.03541746778122638
#     },
#     {
#       "x": 0.7619850071956039,
#       "y": 0.1656415474015609,
#       "weight": 0.22644433097720026,
#       "radius": 0.0972869716923297
#     },
#     {
#       "x": 0.8736083929044367,
#       "y": 0.1075195632359407,
#       "weight": 0.18401443320212257,
#       "radius": 0.07194531632685654
#     },
#     {
#       "x": 0.2180493456293846,
#       "y": 0.5116004016739404,
#       "weight": 0.341059563942342,
#       "radius": 0.08802482158457368
#     },
#     {
#       "x": 0.15491558217844614,
#       "y": 0.217104494779929,
#       "weight": 0.016190998953028495,
#       "radius": 0.02586547399984441
#     }
#   ]
# }
# OUTPUT_JSON:
# {
#   "centers": [
#     {
#       "x": 0.22,
#       "y": 0.5
#     },
#     {
#       "x": 0.76,
#       "y": 0.17
#     },
#     {
#       "x": 0.87,
#       "y": 0.11
#     },
#     {
#       "x": 0.3,
#       "y": 0.94
#     }
#   ]
# }
# ================================================================================
# CASE 7
# INPUT_JSON:
# {
#   "aspect_ratio": 1.0,
#   "k": 4,
#   "hotspots": [
#     {
#       "x": 0.06688397634275167,
#       "y": 0.41324281642825933,
#       "weight": 0.08352189289808078,
#       "radius": 0.028840378715691097
#     },
#     {
#       "x": 0.752111461418534,
#       "y": 0.5112851098756519,
#       "weight": 0.09386131894115253,
#       "radius": 0.023973919558442455
#     },
#     {
#       "x": 0.044807484435657075,
#       "y": 0.7359343862230144,
#       "weight": 0.23520383252462632,
#       "radius": 0.03234797981668769
#     },
#     {
#       "x": 0.733744889835985,
#       "y": 0.6304437186278283,
#       "weight": 0.3563294830256893,
#       "radius": 0.06034233106325221
#     },
#     {
#       "x": 0.8557982138654457,
#       "y": 0.6025572291460339,
#       "weight": 0.017946692485386176,
#       "radius": 0.06586853347491532
#     },
#     {
#       "x": 0.4000793027167511,
#       "y": 0.2487457597737761,
#       "weight": 0.21313678012506485,
#       "radius": 0.03103903954965853
#     }
#   ]
# }
# OUTPUT_JSON:
# {
#   "centers": [
#     {
#       "x": 0.07,
#       "y": 0.7
#     },
#     {
#       "x": 0.75,
#       "y": 0.51
#     },
#     {
#       "x": 0.85,
#       "y": 0.6
#     },
#     {
#       "x": 0.4,
#       "y": 0.2
#     }
#   ]
# }

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi

def _wrap_json_preserve_indent(s: str, width: int = 92) -> list[str]:
    out = []
    for line in s.splitlines():
        if len(line) <= width:
            out.append(line)
            continue
        indent = len(line) - len(line.lstrip(" "))
        prefix = " " * indent
        chunk = line.strip()
        while len(chunk) > width - indent:
            out.append(prefix + chunk[: width - indent])
            chunk = chunk[width - indent :]
        if chunk:
            out.append(prefix + chunk)
    return out

def _case_text_lines(case, wrap_width: int):
    inp = case["input"]
    out = case["output"]
    lines = []
    lines += [f"CASE {case['case']}", "", "INPUT_JSON:"]
    lines += _wrap_json_preserve_indent(json.dumps(inp, indent=2), wrap_width)
    lines += ["", "OUTPUT_JSON:"]
    lines += _wrap_json_preserve_indent(json.dumps(out, indent=2), wrap_width)
    return lines

def _draw_voronoi(ax, inp, out, title_prefix=""):
    aspect = float(inp["aspect_ratio"])
    centers = out["centers"]
    hotspots = inp["hotspots"]

    pts = np.array([[c["x"] * aspect, c["y"]] for c in centers], dtype=float)
    xmin, xmax, ymin, ymax = 0.0, aspect, 0.0, 1.0

    vor = Voronoi(pts)
    regions, vertices = voronoi_finite_polygons_2d(vor, radius=max(aspect, 1.0) * 10.0)

    ax.set_aspect("equal", adjustable="box")
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    for reg in regions:
        poly = vertices[reg]
        clipped = clip_polygon_to_bbox(poly, xmin, xmax, ymin, ymax)
        if clipped.shape[0] < 3:
            continue
        ax.fill(clipped[:, 0], clipped[:, 1], alpha=0.15, linewidth=0)
        ax.plot(
            np.r_[clipped[:, 0], clipped[0, 0]],
            np.r_[clipped[:, 1], clipped[0, 1]],
            linewidth=1,
        )

    ax.scatter(pts[:, 0], pts[:, 1], marker="x")

    for h in hotspots:
        hx, hy = h["x"] * aspect, h["y"]
        ax.scatter([hx], [hy], s=2000 * float(h["weight"]), alpha=0.5)
        ax.add_patch(plt.Circle((hx, hy), float(h["radius"]) * aspect, fill=False, linewidth=1))

    ax.set_title(f"{title_prefix}k={inp['k']} | aspect={inp['aspect_ratio']}", fontsize=9)
    ax.set_xlabel("x (world)")
    ax.set_ylabel("y (world)")

def save_single_page_montage_pdf(
    pdf_path="voronoi_montage_single_page.pdf",
    wrap_width=92,
    font_size=7.3,
    page_width_in=9,
    margin_in=0.25,
    col_gap_in=0.10,
    row_gap_in=0.00,         # set to 0 to remove whitespace between cases
    min_plot_height_in=2.0,
    text_col_frac=0.56,
):
    if not results:
        raise ValueError("results is empty. Run your batch generation first.")

    # Estimate per-line height in inches for monospace
    line_h_in = (font_size * 1.22) / 72.0

    items = []
    for case in results:
        lines = _case_text_lines(case, wrap_width)
        text_h = len(lines) * line_h_in + 0.16
        row_h = max(min_plot_height_in, text_h)
        items.append((case, lines, row_h))

    total_h = (2 * margin_in) + sum(h for _, _, h in items) + row_gap_in * max(0, len(items) - 1)

    fig = plt.figure(figsize=(page_width_in, total_h), dpi=200)
    fig.patch.set_facecolor("white")

    usable_w = page_width_in - 2 * margin_in
    text_w = usable_w * text_col_frac
    plot_w = usable_w - text_w - col_gap_in

    def ncoords(x, y, w, h):
        # Convert inches to normalized figure coords
        return [x / page_width_in, y / total_h, w / page_width_in, h / total_h]

    y_top = total_h - margin_in
    for case, lines, row_h in items:
        y0 = y_top - row_h

        ax_text = fig.add_axes(ncoords(margin_in, y0, text_w, row_h))
        ax_plot = fig.add_axes(ncoords(margin_in + text_w + col_gap_in, y0, plot_w, row_h))

        ax_text.axis("off")
        ax_text.text(
            0.0, 1.0,
            "\n".join(lines),
            va="top", ha="left",
            family="monospace",
            fontsize=font_size,
            transform=ax_text.transAxes,
            clip_on=False,
        )

        _draw_voronoi(ax_plot, case["input"], case["output"], title_prefix=f"Voronoi Case {case['case']} | ")

        y_top = y0 - row_gap_in

    fig.savefig(pdf_path)
    plt.close(fig)
    print(f"Saved single-page montage PDF: {pdf_path}")

def _fmt_num(x: float) -> str:
    # 1.5 -> 1.5, 1.0 -> 1, 0.333333 -> 0.3333
    return f"{float(x):g}"

def build_auto_filename_from_results(prefix="k", suffix=".pdf"):
    if not results:
        raise ValueError("results is empty.")

    inp0 = results[0]["input"]
    k = int(inp0["k"])
    a = float(inp0["aspect_ratio"])
    h = len(inp0.get("hotspots", []))

    return f"{prefix}{k}-h{h}-a{_fmt_num(a)}{suffix}"

# Use it:
auto_name = build_auto_filename_from_results(prefix="k", suffix=".pdf")
save_single_page_montage_pdf(pdf_path=auto_name)
print("Saved as:", auto_name)
# Out:
# Saved single-page montage PDF: k4-h6-a1.pdf
# Saved as: k4-h6-a1.pdf
